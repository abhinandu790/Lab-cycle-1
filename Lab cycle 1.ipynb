# %% [markdown]
#  1.
#  a.Sum od digits

# %%
#integer
num1=int(input("Enter the four digit number :"))
s=0

for i in range(4):
  num2=num1%10
  s=s+num2
  num1=num1//10
print("Sum :",s)

# %% [markdown]
# 1.
# b.Reverse

# %%
num1=int(input("Enter the four digit number :"))
r=0
for i in range(4):
   num3=num1%10
   r=r*10+num3
   num1=num1//10
print("Reverse :",r)

# %% [markdown]
# 1.
# c.Difference between the product of digits at the odd position and the product of digits at the even position.

# %%
num1=int(input("Enter the four digit number :"))
o=1
e=1
for i in range(4):
   num4=num1%10
   if a==0 or a==2:
     e=e*num1
     num1=num1//10
   if a==1 or a==3:
     o=o*num1
     num1=num1//10
print("Difference :",d)

# %% [markdown]
# 2.

# %% [markdown]
# ![Screenshot 2023-12-06 132951.png](data:image/png;base64,...)

# %%
def tr():
  a=int(input("Enter the first side : "))
  b=int(input("Enter the second side : "))
  c=int(input("Enter the third side : "))
  return a,b,c
def area(a,b,c):
  s=(a+b+c)/2
  o=(s*(s-a)*(s-b)*(s-c))**0.5
  return o
print("Enter the values for first triangle:")
a,b,c=tr()
z=area(a,b,c)
print("Enter values for second triangle : ")
d,e,f=tr()
x=area(d,e,f)
toto=z+x
y=(z/toto)*100
l=(x/toto)*100
print("Total area enclosed :",toto)
print("The contribution of fisrt :",y)
print("The contribution of second : ",l)

# %% [markdown]
# 3.
# ![Screenshot 2023-12-06 133617.png](data:image/png;base64,...)

# %%
def sal():
  name=input("Enter employee name :")
  code=input("Enter the code :")
  bp=float(input("Enter your basic pay :"))
  if bp<10000:
     da=0.05*bp
     hra=0.075*bp
     mra=500
     gs=bp+da+hra+mra
     print("Gross Salary :",gs)
    elif(10000<bp and bp<30000):
      da=0.075*bp
     hra=0.05*bp
  mra=2500
  pt=60
  pf=0.08
  gs=bp+da+hra+mra
  print("Gross Salary :",gs)
elif( 30000<bp and bp<50000):
  da=0.011*bp
  hra=0.075*bp
  mra=5000
  pt=60
  gs=bp+da+hra+mra
  print("Gross Salary :",gs)
else:
  da=0.25*bp
  hra=0.11*bp
  mra=7000
  pt=80
  gs=bp+da+hra+mra
  print("Gross Salary :",gs)
def ded(bp):
   if bp<10000:
    pt=20
    pf=0.08*bp
    it=0
    d=pt+pf+it
    de=d
    print("Deduction :",de)
   elif( 10000<bp and bp<30000):
     pt=60
     pf=0.08*bp
     it=0
     d=pt+pf+it
     de=d
     print("Deduction :",de)
   elif (30000<bp and bp<50000) :
     pt=60
     pf=0.11*bp
     it=11
     d=pt+pf+it
     de=d
     print("Deduction :,",de)
   else :
     pt=80
     pf=0.12*bp
     it=20
     d=pt+pt+it
     de=d
     print("Deduction :",de)
def netsal():
  net=gs-de

  print("Payslip")
  print("Name :")
  print("Code :")
  print("Net salary :",net)

# %% [markdown]
# Develop a program to perform the following task:
# a. Define a function to check whether a number is happy or not.
# b. Define a function to print all happy numbers within a range.
# c. Define a function to print first N happy numbers.

# %%
#a
def hap():
  num=int(input("Enter the number :"))
  for i in range(1,100):
    sum=0
    while num>0:
      r=num%10
      sum=+r**2
      num=num//10
    if sum==1:
      return True
    elif num<1:
      num=sum
    else:
      return False
hap()

# %%
#b
def hap():
  a=int(input("Enter the lower limit : "))
  b=int(input("Enter the upper limit : "))
  for i in range (a,b+1):
    c=i
    d=0
    e=0
    o=0
    while e<100:
      sum=0
      while c>0:
        f=c%10
        sum=sum+f**2
        c=c//10
      if sum==1:
        print(i)
      else:
        e=e+1
        c=sum
      if o==0:
        print("There are no happy numbers in this range")

# %%
#c
def happy(a):
  c=0
  i=1
  while(c!=a):
    if check(i)==True:
      print(i)
      c=+1
    i=+1


    if c==a:
      break
a=int(input("Enter the number of happy numbers you want to printed :"))
happy(a)
